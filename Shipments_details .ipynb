# %%
import pandas as pd

# %% [markdown]
# # Table 1

# %% [markdown]
# ####  Getting to Know the Data by Displaying Data Types and shapes and printing the head of data frame , dropping the null Columns

# %%
Table1_df = pd.read_excel (r'Table1.xlsx')
Table1_df = Table1_df.loc[:, ~Table1_df.columns.str.contains('^Unnamed')]

print("Before dropping null columns...\n")
# print(Table1_df.info())
print(Table1_df.shape)
Table1_df=Table1_df.dropna(axis=1, how='all')
print("After droppingnull columns...\n")
# print(Table1_df.info())
print(Table1_df.shape)

Table1_df.head()
# Out:
# Before dropping null columns...
#
# (14845, 32)
# After droppingnull columns...
#
# (14845, 23)
#   FK_PS_SHIPMENT_ID AIR_WAYBILL_TYPE DEPARTURE DESTINATION  \
# 0                 1           MASTER       RUH         ADD
# 1                 2           MASTER       JED         COK
# 2               NaN              NaN       NaN         NaN
# 3               NaN              NaN       NaN         NaN
# 4              USED        ASSEMBLED         7        1790
#
#            FLIGHT_DATE RECEIVER_CORPORATE_BRANCH_ID  \
# 0  2021-01-22 03:00:00                        20434
# 1  2021-01-21 23:00:00                          221
# 2                  NaN                          NaN
# 3                  NaN                          NaN
# 4               443346                          NaN
#
#           RECEIVER_CORPORATE_BRANCH_NAME_AR  \
# 0     مكتب خطوط المنال للشحن الجوي  - السلي
# 1  مؤسسة افيان الدولية للشحن الجوي - بريمان
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#       RECEIVER_CORPORATE_BRANCH_NAME_EN SEND_CORPORATE_BRANCH_ID  \
# 0  Al Manal Lines For Air Cargo - السلي                    20405
# 1       Avian Saudia for Cargo - Bryman                      221
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                  PREPAID
#
#               SEND_CORPORATE_BRANCH_NAME_AR  ...  \
# 0      وكالة نسمة روان للشحن الجوي - الفوطة  ...
# 1  مؤسسة افيان الدولية للشحن الجوي - بريمان  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       PPD  ...
#
#                   AIR_WAYBILL_FROM AIR_WAYBILL_STATUS SHIPMENT_STATUS  \
# 0   Nesma Rawan Air Cargo539486669               USED       ASSEMBLED
# 1  Avian Saudia for Cargo582341557                NaN             NaN
# 2                              NaN                NaN             NaN
# 3                              NaN                NaN             NaN
# 4                              NaN                NaN             NaN
#
#   NUMBER_OF_PACKAGES SHIPMENT_TOTAL SHIPMENT_TOTAL_WEIGH_CHARGES  \
# 0                  5           1740                         1740
# 1                NaN            NaN                          NaN
# 2                NaN            NaN                          NaN
# 3                NaN            NaN                          NaN
# 4                NaN            NaN                          NaN
#
#   ACCOUNTING_INFORMATION PAYMENT_TYPE               RECEIVED_DATE  \
# 0                prepaid          PPD  2021-01-18 16:33:10.937000
# 1                    NaN          NaN                         NaN
# 2                    NaN          NaN                         NaN
# 3                    NaN          NaN                         NaN
# 4                    NaN          NaN                         NaN
#
#                             RECEIVED_By
# 0  وكالة نسمة روان للشحن الجوي - الفوطة
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# #### dropping the null rows and displaying the number of rows and columns before and after , remove newlines in strings with space

# %%
print("Before dropping null rows...\n")
print(Table1_df.shape)
Table1_df.dropna(axis = 0, how = 'all', inplace = True)
print("After dropping null rows...\n")
print(Table1_df.shape)
Table1_df = Table1_df.replace(r'\\n',  ' ', regex=True) 
Table1_df.tail()
# Out:
# Before dropping null rows...
#
# (14845, 23)
# After dropping null rows...
#
# (10862, 23)
#       FK_PS_SHIPMENT_ID AIR_WAYBILL_TYPE DEPARTURE DESTINATION  \
# 14840             29070           MASTER       JED         COK
# 14841             28887           MASTER       JED         COK
# 14842             28888           MASTER       JED         COK
# 14843             28893           MASTER       DMM         DEL
# 14844             29144           MASTER       JED         NRT
#
#                FLIGHT_DATE RECEIVER_CORPORATE_BRANCH_ID  \
# 14840  2021-04-22 08:30:00                          217
# 14841  2021-04-22 08:30:00                          217
# 14842  2021-04-22 08:30:00                          217
# 14843  2021-04-20 00:00:00                            6
# 14844  2021-04-24 00:00:00                          217
#
#                        RECEIVER_CORPORATE_BRANCH_NAME_AR  \
# 14840                     وكالة شتا للشحن الجوي - النخيل
# 14841                     وكالة شتا للشحن الجوي - النخيل
# 14842                     وكالة شتا للشحن الجوي - النخيل
# 14843  شركة وكالة إيلاء للنقل الجوي المحدودة - الخالد...
# 14844                     وكالة شتا للشحن الجوي - النخيل
#
#                        RECEIVER_CORPORATE_BRANCH_NAME_EN  \
# 14840                       Shita Air Cargo - Al Nakheel
# 14841                       Shita Air Cargo - Al Nakheel
# 14842                       Shita Air Cargo - Al Nakheel
# 14843  Elaa Air Transport Agency Co Ltd - Al Khalidiy...
# 14844                       Shita Air Cargo - Al Nakheel
#
#       SEND_CORPORATE_BRANCH_ID  \
# 14840                      217
# 14841                      217
# 14842                      217
# 14843                        6
# 14844                      217
#
#                            SEND_CORPORATE_BRANCH_NAME_AR  ...  \
# 14840                     وكالة شتا للشحن الجوي - النخيل  ...
# 14841                     وكالة شتا للشحن الجوي - النخيل  ...
# 14842                     وكالة شتا للشحن الجوي - النخيل  ...
# 14843  شركة وكالة إيلاء للنقل الجوي المحدودة - الخالد...  ...
# 14844                     وكالة شتا للشحن الجوي - النخيل  ...
#
#       AIR_WAYBILL_FROM AIR_WAYBILL_STATUS SHIPMENT_STATUS NUMBER_OF_PACKAGES  \
# 14840              333               USED       ASSEMBLED                  0
# 14841              333               USED       ASSEMBLED                  0
# 14842              333               USED       ASSEMBLED                  0
# 14843                8               USED       ASSEMBLED                  0
# 14844              207               USED       ASSEMBLED                  0
#
#       SHIPMENT_TOTAL SHIPMENT_TOTAL_WEIGH_CHARGES ACCOUNTING_INFORMATION  \
# 14840        8898.71                     8898.708        FREIGHT PREPAID
# 14841         8599.5                       8599.5        FREIGHT PREPAID
# 14842        9507.68                      9507.68        FREIGHT PREPAID
# 14843          14184                        14184                     PP
# 14844         6112.8                       6112.8                     PP
#
#       PAYMENT_TYPE               RECEIVED_DATE  \
# 14840          PPD  2021-04-17 22:59:46.063000
# 14841          PPD  2021-04-17 22:59:46.123000
# 14842          PPD  2021-04-17 22:59:46.187000
# 14843          PPD  2021-04-18 01:00:22.850000
# 14844          PPD  2021-04-18 11:01:37.343000
#
#                                              RECEIVED_By
# 14840                     وكالة شتا للشحن الجوي - النخيل
# 14841                     وكالة شتا للشحن الجوي - النخيل
# 14842                     وكالة شتا للشحن الجوي - النخيل
# 14843  شركة وكالة إيلاء للنقل الجوي المحدودة - الخالد...
# 14844                     وكالة شتا للشحن الجوي - النخيل
#
# [5 rows x 23 columns]

# %% [markdown]
# #### remove row that has 10 or more missing value

# %%
print("Before dropping null rows...\n")
print(Table1_df.shape)

Table1_df = Table1_df.dropna( thresh=10 )
Table1_df = Table1_df.fillna('None')

print("After dropping null rows...\n")
print(Table1_df.shape)
# Out:
# Before dropping null rows...
#
# (10862, 23)
# After dropping null rows...
#
# (9480, 23)

# %% [markdown]
# #### displying the count of each unique value in all columns

# %%
print('\n\n########## RECEIVER NAME ###############\n',Table1_df['RECEIVER_CORPORATE_BRANCH_NAME_EN'].value_counts())
print('\n\n########## RECEIVER ID ###############\n',Table1_df['RECEIVER_CORPORATE_BRANCH_ID'].value_counts())

print('\n\n########## SEND NAME ###############\n',Table1_df['SEND_CORPORATE_BRANCH_NAME_AR'].value_counts())
print('\n\n########## SEND ID ###############\n' , Table1_df['SEND_CORPORATE_BRANCH_ID'].value_counts())

print('\n\n############# AIR WAYBILL TYPE ############\n', Table1_df['AIR_WAYBILL_TYPE'].value_counts())
print('\n\n############# AIR WAYBILL STATUS ############\n',Table1_df['AIR_WAYBILL_STATUS'].value_counts())

print(Table1_df['DEPARTURE'].value_counts(),'\n\n#########################\n')
# Out:
# ########## RECEIVER NAME ###############
#  None                                                                              1193
# Al Manal Lines For Air Cargo - السلي                                              1062
# Elaa Air Transport Agency Co Ltd - Al Khalidiyyah Al Janubiyyah                   1033
# Aramex Saudi Limited - Al Khalidiyyah Al Janubiyyah                                613
# Avian Saudia for Cargo - Bryman                                                    560
#                                                                                   ...
# 1425                                                                                 1
# ABCL - Ar Rawdah                                                                     1
# MOHAMMAD ARIFUR RAHMAN,Chittagong,Bangladesh,01820840033,CHITTAGONG,BANGLADESH       1
# Skyline international cargo agency - Al Souq                                         1
# وكالة الجسور الجويه للشجن الجوي - المشاعل                                            1
# Name: RECEIVER_CORPORATE_BRANCH_NAME_EN, Length: 83, dtype: int64
#
#
# ########## RECEIVER ID ###############
#  20434                     1062
# 6                         1033
# 39                         613
# 221                        560
# 20431                      543
#                           ...
# تسيغا يبرها - تكلو           1
# مححسنان عبد  جالي            1
# يوجي  تيو ايجي               1
# حسين   مياه                  1
# نيقستي ابرها  كفليمريم       1
# Name: RECEIVER_CORPORATE_BRANCH_ID, Length: 531, dtype: int64
#
#
# ########## SEND NAME ###############
#  PPD                                                           1255
# شركة وكالة إيلاء للنقل الجوي المحدودة - الخالدية الجنوبية      687
# وكالة نسمة روان للشحن الجوي - الفوطة                           555
# وكالة شتا للشحن الجوي - النخيل                                 463
# شركة ربل الدولية للتجارة وخدمات الشحن المحدودة - حي بريمان     397
#                                                               ...
# شركة وكالة إيلاء للنقل الجوي المحدودة - الهنداوية                1
# 2021-01-27 20:28:53.803000                                       1
# شركة سمسا للنقل السريع المحدودة - النخيل                         1
# الرابط الجوي - المرقب                                            1
# فرع شركة الجسور الجوية للخدمات اللوجستيةجدة - الروضة             1
# Name: SEND_CORPORATE_BRANCH_NAME_AR, Length: 118, dtype: int64
#
#
# ########## SEND ID ###############
#  6                                                   687
# 20405                                               555
# 217                                                 463
# 229                                                 397
# FREIGHT PREPAID                                     359
#                                                    ...
# Smsa Express Transportation Company Ltd505717616      1
# P  P                                                  1
# Air bridges cargo - Al Mashael                        1
# FREIGHT P[REPAID                                      1
# freight prepaid                                       1
# Name: SEND_CORPORATE_BRANCH_ID, Length: 157, dtype: int64
#
#
# ############# AIR WAYBILL TYPE ############
#  MASTER                                                       8214
# ASSEMBLED                                                    1103
# SPECIAL_CARGO                                                 147
# APPROVED_BY_ACCREDITED                                          5
# 10                                                              1
# USED                                                            1
# Aramex Saudi Limited542002016                                   1
# RABEL INT TRADING CARGO SERVICES CO LTD557666618                1
# 382                                                             1
# شركة وكالة إيلاء للنقل الجوي المحدودة - الخالدية الجنوبية       1
# EA1613639009070GO                                               1
# شركة ارامكس السعودية المحدودة - الخالدية الجنوبية               1
# ALMunawala Air Cargo Co - Al Mashael                            1
# Aramex Saudi Limited - As Sulay                                 1
# شركة ارامكس السعودية المحدودة - مخطط الدخل المحدود              1
# Name: AIR_WAYBILL_TYPE, dtype: int64
#
#
# ############# AIR WAYBILL STATUS ############
#  USED                                                                                                                                                                                5391
# None                                                                                                                                                                                3902
# SPECIAL_CARGO                                                                                                                                                                        149
# APPROVED_BY_ACCREDITED                                                                                                                                                                15
# ABDUSSALAM HOLILI SAMSUL. DKK  Passport No : B - 3805541 C/O : PT.ANTARAN SUKSES EXPRESS. JL; RADEN FATAH 10 CILEDUG TANGERANG BANTEN. TEL; 021 – 7306080  FAX.; 021 – 70633029       10
# ,Izmir,Turkey,9460245731,YEFE DIS TICARET LTD.STI                                                                                                                                      1
# Tun Pehin Seri Haji Abdul Taib Mahmud ,Kuala Lumpur,Malaysia,0173229112,No. 14, Jalan Tunku Putra Off Taman Duta, 50480 Kuala Lumpur.                                                  1
#  Household Goods                                                                                                                                                                       1
#  EFFECTS AND HOUSEHOLD GOODS                                                                                                                                                           1
# شركة ربل الدولية للتجارة وخدمات الشحن المحدودة - حي بريمان                                                                                                                             1
# PPD                                                                                                                                                                                    1
#  USED PERSONAL EFFECTS AND                                                                                                                                                             1
#  & Household Goods                                                                                                                                                                     1
# شركة ارامكس السعودية المحدودة - السلي                                                                                                                                                  1
#                                                                                                                                                                                        1
# محمد ألطاف  حسين                                                                                                                                                                       1
#  EFFECTS                                                                                                                                                                               1
# ,Karachi,Pakistan,92111000165,BANK AL HABIB LIMITED                                                                                                                                    1
# Name: AIR_WAYBILL_STATUS, dtype: int64
# RUH    2949
# DMM    2644
# JED    2552
# 1       263
# 2       110
#        ...
# 45        1
# 107       1
# 111       1
# 55        1
# 71        1
# Name: DEPARTURE, Length: 123, dtype: int64
#
# #########################

# %% [markdown]
# #### fill missing ID columns with zeros

# %%
Table1_df[['RECEIVER_CORPORATE_BRANCH_ID']] = Table1_df[['RECEIVER_CORPORATE_BRANCH_ID']].fillna(0)
Table1_df[['SEND_CORPORATE_BRANCH_ID']] = Table1_df[['RECEIVER_CORPORATE_BRANCH_ID']].fillna(0)

# %%
Table1_df.isnull().sum()
Table1_df[['SEND_CORPORATE_BRANCH_NAME_AR','SEND_CORPORATE_BRANCH_NAME_EN']].head()
Table1_df['SEND_CORPORATE_BRANCH_NAME_EN'].unique()
# Out:
# array(['Nesma Rawan Air Cargo - Al Futah',
#        'Avian Saudia for Cargo - Bryman',
#        'Agility Air Cargo - Al Mohammadiyyah', ...,
#        datetime.datetime(2021, 3, 29, 14, 31, 54, 440000),
#        datetime.datetime(2021, 3, 29, 14, 32, 11, 180000),
#        'ELM company Accredited test two - As Sulimaniyah'], dtype=object)

# %% [markdown]
# # Table 2

# %% [markdown]
# #### Getting to Know the Data by Displaying Data Types and shapes and printing the head of data frame , dropping the null Columns

# %%
Table2_df = pd.read_excel (r'Table2.xlsx')
Table2_df = Table2_df.loc[:, ~Table2_df.columns.str.contains('^Unnamed')]

print("Before dropping null columns...\n")
# print(Table1_df.info())
print(Table2_df.shape)
Table2_df=Table2_df.dropna(axis=1, how='all')
print("After droppingnull columns...\n")
# print(Table1_df.info())
print(Table2_df.shape)
Table2_df.tail()
# Out:
# Before dropping null columns...
#
# (38193, 41)
# After droppingnull columns...
#
# (38193, 26)
#            PK_PS_SHIPMENT_ID CURRENT_CORPORATE_BRANCH_ID  \
# 38188       WILBURY, HITCHIN                         NaN
# 38189        ENGLAND SG4 OTY                         NaN
# 38190  TEL: +44 772 7011 580                         NaN
# 38191                  29148                         197
# 38192              MELBOURNE                         NaN
#
#         CURRENT_CORPORATE_BRANCH_NAME_AR  \
# 38188                                NaN
# 38189                                NaN
# 38190                                NaN
# 38191  وكاله خدمات الشحن السريع - المربع
# 38192                                NaN
#
#                CURRENT_CORPORATE_BRANCH_NAME_EN SHIPMENT_STATUS  \
# 38188                                       NaN             NaN
# 38189                                       NaN             NaN
# 38190                                       NaN             NaN
# 38191  EXPRESS FORWARDING SERVICES - Al Murabba       ASSEMBLED
# 38192                                       NaN             NaN
#
#       SHIPMENT_TOTAL_WEIGH_CHARGES SHIPMENT_OTHER_CHARGES SHIPMENT_TAX  \
# 38188                          NaN                    NaN          NaN
# 38189                          NaN                    NaN          NaN
# 38190                          NaN                    NaN          NaN
# 38191                         7512                      0            0
# 38192                          NaN                    NaN          NaN
#
#       SHIPMENT_TOTAL CHARGES_TYPE  ... AIRLINE_CODE COUNTRY_CODE SHIPPER_TYPE  \
# 38188            NaN          NaN  ...          NaN          NaN          NaN
# 38189            NaN          NaN  ...          NaN          NaN          NaN
# 38190            NaN          NaN  ...          NaN          NaN          NaN
# 38191           7512          NaN  ...           EY          ARE     RESIDENT
# 38192            NaN          NaN  ...          NaN          NaN          NaN
#
#       SHIPPER_ID_EXPIRY_DATE RECEIVER_COUNTRY_ID RECEIVER_COUNTRY_AR  \
# 38188                    NaN                 NaN                 NaN
# 38189                    NaN                 NaN                 NaN
# 38190                    NaN                 NaN                 NaN
# 38191    1989-11-09 00:00:00                  12            أستراليا
# 38192                    NaN                 NaN                 NaN
#
#       RECEIVER_COUNTRY_EN RECEIVER_CITY_ID RECEIVER_CITY_AR RECEIVER_CITY_EN
# 38188                 NaN              NaN              NaN              NaN
# 38189                 NaN              NaN              NaN              NaN
# 38190                 NaN              NaN              NaN              NaN
# 38191           Australia              131           ملبورن        Melbourne
# 38192                 NaN              NaN              NaN              NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# #### dropping the null rows and displaying the number of rows and columns before and after , remove newlines in strings with space

# %%
print("Before dropping null rows...\n")
print(Table2_df.shape)
Table2_df.dropna(axis = 0, how = 'all', inplace = True)
print("After dropping null rows...\n")
print(Table2_df.shape)
Table2_df = Table2_df.replace(r'\\n',  ' ', regex=True) 
Table2_df.tail()
# Out:
# Before dropping null rows...
#
# (38193, 26)
# After dropping null rows...
#
# (37122, 26)
#            PK_PS_SHIPMENT_ID CURRENT_CORPORATE_BRANCH_ID  \
# 38188       WILBURY, HITCHIN                         NaN
# 38189        ENGLAND SG4 OTY                         NaN
# 38190  TEL: +44 772 7011 580                         NaN
# 38191                  29148                         197
# 38192              MELBOURNE                         NaN
#
#         CURRENT_CORPORATE_BRANCH_NAME_AR  \
# 38188                                NaN
# 38189                                NaN
# 38190                                NaN
# 38191  وكاله خدمات الشحن السريع - المربع
# 38192                                NaN
#
#                CURRENT_CORPORATE_BRANCH_NAME_EN SHIPMENT_STATUS  \
# 38188                                       NaN             NaN
# 38189                                       NaN             NaN
# 38190                                       NaN             NaN
# 38191  EXPRESS FORWARDING SERVICES - Al Murabba       ASSEMBLED
# 38192                                       NaN             NaN
#
#       SHIPMENT_TOTAL_WEIGH_CHARGES SHIPMENT_OTHER_CHARGES SHIPMENT_TAX  \
# 38188                          NaN                    NaN          NaN
# 38189                          NaN                    NaN          NaN
# 38190                          NaN                    NaN          NaN
# 38191                         7512                      0            0
# 38192                          NaN                    NaN          NaN
#
#       SHIPMENT_TOTAL CHARGES_TYPE  ... AIRLINE_CODE COUNTRY_CODE SHIPPER_TYPE  \
# 38188            NaN          NaN  ...          NaN          NaN          NaN
# 38189            NaN          NaN  ...          NaN          NaN          NaN
# 38190            NaN          NaN  ...          NaN          NaN          NaN
# 38191           7512          NaN  ...           EY          ARE     RESIDENT
# 38192            NaN          NaN  ...          NaN          NaN          NaN
#
#       SHIPPER_ID_EXPIRY_DATE RECEIVER_COUNTRY_ID RECEIVER_COUNTRY_AR  \
# 38188                    NaN                 NaN                 NaN
# 38189                    NaN                 NaN                 NaN
# 38190                    NaN                 NaN                 NaN
# 38191    1989-11-09 00:00:00                  12            أستراليا
# 38192                    NaN                 NaN                 NaN
#
#       RECEIVER_COUNTRY_EN RECEIVER_CITY_ID RECEIVER_CITY_AR RECEIVER_CITY_EN
# 38188                 NaN              NaN              NaN              NaN
# 38189                 NaN              NaN              NaN              NaN
# 38190                 NaN              NaN              NaN              NaN
# 38191           Australia              131           ملبورن        Melbourne
# 38192                 NaN              NaN              NaN              NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# #### remove row that has 13 or more missing value

# %%
print("Before dropping null rows...\n")
print(Table2_df.shape)

Table2_df = Table2_df.dropna( thresh=13 )
Table2_df = Table2_df.fillna('None')
print("After dropping null rows...\n")
print(Table2_df.shape)
Table2_df.tail()
# Out:
# Before dropping null rows...
#
# (37122, 26)
# After dropping null rows...
#
# (18907, 26)
#       PK_PS_SHIPMENT_ID CURRENT_CORPORATE_BRANCH_ID  \
# 38177             29144                         207
# 38182             29145                         239
# 38183             29146                         197
# 38186             29147                         270
# 38191             29148                         197
#
#                 CURRENT_CORPORATE_BRANCH_NAME_AR  \
# 38177                 شتا للشحن الجوي - بني مالك
# 38182   شركة المناولة للشحن المحدودة - الهندواية
# 38183          وكاله خدمات الشحن السريع - المربع
# 38186  مؤسسة الخط او المسار للشحن الجوي - الربوة
# 38191          وكاله خدمات الشحن السريع - المربع
#
#                      CURRENT_CORPORATE_BRANCH_NAME_EN SHIPMENT_STATUS  \
# 38177                    Shita Air Cargo - Bani Malik       ASSEMBLED
# 38182            AL Munawla Cargo Co - Al-Hindaweyyah       ASSEMBLED
# 38183        EXPRESS FORWARDING SERVICES - Al Murabba       ASSEMBLED
# 38186  SKYWAY FOR AIR CARGO ESTABLISHMENT - Al Rabwah       ASSEMBLED
# 38191        EXPRESS FORWARDING SERVICES - Al Murabba       ASSEMBLED
#
#       SHIPMENT_TOTAL_WEIGH_CHARGES SHIPMENT_OTHER_CHARGES SHIPMENT_TAX  \
# 38177                       6112.8                      0            0
# 38182                         1683                      0            0
# 38183                        206.4                      0            0
# 38186                        11280                      0            0
# 38191                         7512                      0            0
#
#       SHIPMENT_TOTAL CHARGES_TYPE  ... AIRLINE_CODE COUNTRY_CODE SHIPPER_TYPE  \
# 38177         6112.8         None  ...           EK          ARE     RESIDENT
# 38182           1683         None  ...           SV          SAU    CORPORATE
# 38183          206.4         None  ...           SV          SAU     RESIDENT
# 38186          11280         None  ...           SV          SAU    CORPORATE
# 38191           7512         None  ...           EY          ARE     RESIDENT
#
#       SHIPPER_ID_EXPIRY_DATE RECEIVER_COUNTRY_ID        RECEIVER_COUNTRY_AR  \
# 38177    1990-11-30 00:00:00                 102                    اليابان
# 38182                   None                   7   الأمارات العربية المتحدة
# 38183    1989-11-09 00:00:00                 171                        قطر
# 38186                   None                  72            المملكة المتحدة
# 38191    1989-11-09 00:00:00                  12                   أستراليا
#
#         RECEIVER_COUNTRY_EN RECEIVER_CITY_ID RECEIVER_CITY_AR RECEIVER_CITY_EN
# 38177                 Japan             1532            طوكيو            Tokyo
# 38182  United Arab Emirates               64              دبي            Dubai
# 38183                 Qatar             2973           الدوحة             Doha
# 38186        United Kingdom              456             لندن           London
# 38191             Australia              131           ملبورن        Melbourne
#
# [5 rows x 26 columns]

# %% [markdown]
# #### displying the count of each unique value in all columns

# %%
print('\n\n########## CURRENT NAME ###############\n',Table2_df['CURRENT_CORPORATE_BRANCH_NAME_EN'].value_counts())
print('\n\n########## CURRENT ID ###############\n',Table2_df['CURRENT_CORPORATE_BRANCH_ID'].value_counts())

print('\n\n########## RECEIVER_COUNTRY_EN ###############\n',Table2_df['RECEIVER_COUNTRY_EN'].value_counts())
print('\n\n########## RECEIVER_COUNTRY_AR ###############\n' , Table2_df['RECEIVER_COUNTRY_AR'].value_counts())

print('\n\n############# SHIPMENT_STATUS ############\n', Table2_df['SHIPMENT_STATUS'].value_counts())
# Out:
# ########## CURRENT NAME ###############
#  Nesma Rawan Air Cargo - Al Futah                                        1673
# Al Manal Lines For Air Cargo - السلي                                     942
# Elaa Air Transport Agency Co Ltd - King Khalid International Airport     937
# RABEL INT TRADING CARGO SERVICES CO LTD - Bryman District                920
# Kamal H Alwassia Co LTD - Mishrifah                                      849
#                                                                         ...
# Air link for air cargo - Al Futah                                          1
# MARSA EMDAD Freight Forwarder Co - An Nada                                 1
# ABCL - Ar Rawdah                                                           1
# Air link air cargo - Al Souq                                               1
# basem international - As Sarawat                                           1
# Name: CURRENT_CORPORATE_BRANCH_NAME_EN, Length: 144, dtype: int64
#
#
# ########## CURRENT ID ###############
#  20405                                             1673
# 20434                                              942
# 10383                                              937
# 229                                                920
# 284                                                849
#                                                   ...
# كوني اند ناجل المحدودة   جدة الاندلس - الأندلس       1
# None                                                 1
# 136                                                  1
# 281                                                  1
# 255                                                  1
# Name: CURRENT_CORPORATE_BRANCH_ID, Length: 138, dtype: int64
#
#
# ########## RECEIVER_COUNTRY_EN ###############
#  Ethiopia                3602
# Bangladesh              3093
# United Arab Emirates    1920
# India                   1877
# Philippines             1310
#                         ...
# Turkmenistan               1
# Peru                       1
# Togo                       1
# Slovenia                   1
# Namibia                    1
# Name: RECEIVER_COUNTRY_EN, Length: 126, dtype: int64
#
#
# ########## RECEIVER_COUNTRY_AR ###############
#   أثيوبيا                     3602
#  بنغلاديش                    3093
#  الأمارات العربية المتحدة    1920
#  الهند                       1877
#  الفلبين                     1310
#                              ...
#  رواندا                         1
#  سيشيل                          1
#  بنين                           1
#  الغابون                        1
#  ناميبيا                        1
# Name: RECEIVER_COUNTRY_AR, Length: 128, dtype: int64
#
#
# ############# SHIPMENT_STATUS ############
#  AT_AIRPORT                8580
# APPROVED_AT_AIRPORT       6077
# ASSEMBLED                 1989
# SPECIAL_CARGO              792
# LOADED                     760
# APPROVED_AT_AIRPORT2       215
# NEW                        185
# APPROVED_BY_ACCREDITED     173
# AT_ACCREDITED               82
# REJECTED_BY_ACCREDITED      39
# REJECTED_AT_AIRPORT         10
# None                         2
# 0                            1
# 5220                         1
# 11920                        1
# Name: SHIPMENT_STATUS, dtype: int64

# %% [markdown]
# # Table 3

# %% [markdown]
# #### Getting to Know the Data by Displaying Data Types and shapes and printing the head of data frame , dropping the null Columns

# %%
Table3_df = pd.read_excel (r'Table3.xlsx')
Table3_df = Table3_df.loc[:, ~Table3_df.columns.str.contains('^Unnamed')]
Table3_df = Table3_df.loc[:, ~Table3_df.columns.str.contains('^DESCRIPTION_AR')]
print("Before dropping null columns...\n")
# print(Table1_df.info())
print(Table3_df.shape)
Table3_df=Table3_df.dropna(axis=1, how='all')
print("After droppingnull columns...\n")
# print(Table1_df.info())
print(Table3_df.shape)

Table3_df.head()
# Out:
# Before dropping null columns...
#
# (2144, 13)
# After droppingnull columns...
#
# (2144, 12)
#    PK_PS_SHIPMENT_ITEM_ID  FK_PS_SHIPMENT_ID  NUMBER_OF_PIECES  \
# 0                       1                  1                 5
# 1                       2                  2                 7
# 2                       3                  3                 1
# 3                       4                  4                 1
# 4                       5                  5                 4
#
#    CHARGEABLE_WEIGHT  GROSS_WEIGHT WEIGHT_UNIT  RATE  HEIGHT  WIDTH  LENGTH  \
# 0                  1         348.0          KG     1    50.0   40.0    30.0
# 1                  1         179.2          KG     1    40.0   49.0    50.0
# 2                  1         263.0          KG     1    42.0   35.0   158.0
# 3                  1         144.0          KG     1    58.0   74.0    79.0
# 4                  1         186.0          KG     1    33.0   55.0   100.0
#
#    VOLUME          DESCRIPTION
# 0   10.00  clothes food etc...
# 1   16.33     PERSONAL EFFECTS
# 2   38.71  OIL FIELD EQUIPMENT
# 3   56.51    OILWELL EQUIPMENT
# 4   30.25     PERSONAL EFFECTS

# %% [markdown]
# #### dropping the null rows and displaying the number of rows and columns before and after , remove newlines in strings with space

# %%
print("Before dropping null rows...\n")
print(Table3_df.shape)
Table3_df.dropna(axis = 0, how = 'all', inplace = True)
print("After dropping null rows...\n")
print(Table3_df.shape)
Table3_df = Table3_df.replace(r'\\n',  ' ', regex=True) 
Table3_df.tail()
# Out:
# Before dropping null rows...
#
# (2144, 12)
# After dropping null rows...
#
# (2144, 12)
#       PK_PS_SHIPMENT_ITEM_ID  FK_PS_SHIPMENT_ID  NUMBER_OF_PIECES  \
# 2139                    2140               1359                 1
# 2140                    2141               1360                 1
# 2141                    2142               1361                 1
# 2142                    2143               1362                 1
# 2143                    2144               1363                 3
#
#       CHARGEABLE_WEIGHT  GROSS_WEIGHT WEIGHT_UNIT  RATE  HEIGHT  WIDTH  \
# 2139                  1       552.000          KG     1    40.0   50.0
# 2140                  1       348.993          KG     1    60.0   50.0
# 2141                  1         2.000          KG     1    24.0   26.0
# 2142                  1       344.000          KG     1    45.0   50.0
# 2143                  1       162.000          KG     1    51.0   61.0
#
#       LENGTH  VOLUME                DESCRIPTION
# 2139    60.0   20.00                    Clothes
# 2140    60.0   30.00            personal effect
# 2141    35.0    3.64      Electrical Equipments
# 2142    45.0   16.88          PERSONAL EFFECTS
# 2143    48.0   24.89  EQUIPMENT BACK FROM RALLY

# %% [markdown]
# #### remove row that has 6 or more missing value

# %%
print("Before dropping null rows...\n")
print(Table3_df.shape)

Table3_df = Table3_df.dropna( thresh=6 )
Table3_df = Table3_df.fillna('None')

print("After dropping null rows...\n")
print(Table3_df.shape)
# Out:
# Before dropping null rows...
#
# (2144, 12)
# After dropping null rows...
#
# (2144, 12)

# %%
Table3_df["DESCRIPTION"] = Table3_df["DESCRIPTION"].str.lower()
Table3_df.head()
# Out:
#    PK_PS_SHIPMENT_ITEM_ID  FK_PS_SHIPMENT_ID  NUMBER_OF_PIECES  \
# 0                       1                  1                 5
# 1                       2                  2                 7
# 2                       3                  3                 1
# 3                       4                  4                 1
# 4                       5                  5                 4
#
#    CHARGEABLE_WEIGHT  GROSS_WEIGHT WEIGHT_UNIT  RATE  HEIGHT  WIDTH  LENGTH  \
# 0                  1         348.0          KG     1    50.0   40.0    30.0
# 1                  1         179.2          KG     1    40.0   49.0    50.0
# 2                  1         263.0          KG     1    42.0   35.0   158.0
# 3                  1         144.0          KG     1    58.0   74.0    79.0
# 4                  1         186.0          KG     1    33.0   55.0   100.0
#
#    VOLUME          DESCRIPTION
# 0   10.00  clothes food etc...
# 1   16.33     personal effects
# 2   38.71  oil field equipment
# 3   56.51    oilwell equipment
# 4   30.25     personal effects

# %%
Table1_df.to_excel("Table1_df.xlsx") 
Table2_df.to_excel("Table2_df.xlsx") 
Table3_df.to_excel("Table3_df.xlsx")
